# %%
import sys
sys.path.append("../../")

import akshare as ak
import time
import polars as pl

from workspace.playground.stocksector import *

# %%
start_date, end_date = '20241130', '20251218'

data = stock_sector_net_grouwth_all(start_date, end_date)
data.tail(5)
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# shape: (5, 88)
# ┌────────────┬───────────┬──────────┬──────────┬───┬──────────┬────────────┬──────────┬──────────┐
# │ date       ┆ benchmark ┆ 医药商业 ┆ 航天航空 ┆ … ┆ 能源金属 ┆ 电子化学品 ┆ 电源设备 ┆ 电池     │
# │ ---        ┆ ---       ┆ ---      ┆ ---      ┆   ┆ ---      ┆ ---        ┆ ---      ┆ ---      │
# │ str        ┆ f64       ┆ f64      ┆ f64      ┆   ┆ f64      ┆ f64        ┆ f64      ┆ f64      │
# ╞════════════╪═══════════╪══════════╪══════════╪═══╪══════════╪════════════╪══════════╪══════════╡
# │ 2025-12-12 ┆ 1.2063    ┆ 0.944445 ┆ 1.050598 ┆ … ┆ 1.291163 ┆ 1.074807   ┆ 1.420563 ┆ 1.177748 │
# │ 2025-12-15 ┆ 1.196907  ┆ 0.962066 ┆ 1.067116 ┆ … ┆ 1.274942 ┆ 1.087363   ┆ 1.415846 ┆ 1.172697 │
# │ 2025-12-16 ┆ 1.177956  ┆ 0.966742 ┆ 1.062759 ┆ … ┆ 1.275539 ┆ 1.097037   ┆ 1.391469 ┆ 1.165131 │
# │ 2025-12-17 ┆ 1.200923  ┆ 0.965547 ┆ 1.033086 ┆ … ┆ 1.326951 ┆ 1.07366    ┆ 1.395178 ┆ 1.175354 │
# ...

# %%
data.write_csv('data/二级市场板块回报率.csv')

# %% [markdown]
# ## 如果想查看html 文件，请启动server
# !python show_server.py
#
# 然后在浏览器中打开 http://localhost:8000/二级市场板块回报分析.html
